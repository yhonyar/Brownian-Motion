# %% [markdown]
# # Brownian Motion

# %% [markdown]
# 1.) $B_0=0$
#
# 2.) $B$ has stationary and indepent increments
#
# 3.) $B_t-B_s\sim N(0,t-s)$ with $0<s<t$
#
# (Discrete sense)
#
# Suppose we had time increments $0=t_0<t_1<\dots <t_k=T$
# - $B_{t_0}=B_0=0$
# - $B_{t_1}=B_0+B_{t_1}-B_{t_0}$
# - $B_{t_2}=B_{t_0}+B_{t_2}-B_{t_1}$
# - (generally) $B_{t_i}=B_{t_{i-2}}+B_{t_i}-B_{t_{i-1}}, i \in \mathbb{N}$
#
# Suppose we had a standard normal viarable $Z\sim N(0,1)$ and first index of a Brownian motion given by $B_{t_1}=B_0+B_{t_1}-B_{t_0}=0+B_{t_1}-B_{t_0}\sim N(0,t_1)$
# If we are to scale $Z$ by $\sqrt{t_1}$ it follows $B_{t_1}=\sqrt{t_1}Z$ in the sense that have the same distribution function.
#
# We know that any shift/scale (by some constants $a,b\in\mathbb{R}$ normal random variable is also normal, thus we can look for the expectation and varaince.
#
# - $\mathbb{E}(\sqrt{t_1}Z)=\sqrt{t_1}\mathbb{E}(Z)=0$
# - $Var(\sqrt{t_1}Z)=t_1Var(Z)=t_1$
# $\implies \sqrt{t_1}Z \sim N(0,t_1) \implies \sqrt{t_1}Z_{t_1}=B_{t_1}$
#
# Simulation Brownian motions
# - $B_{t_0}=B_0=0$
# - $B_{t_1}=\sqrt{t_1}Z_{t_1}$
# - $B_{t_2}=\sqrt{t_1}Z_{t_1}+\sqrt{t_2-t_1}Z_{t_2}$
# - $B_{t_i}=B_{t_{i-2}}+B_{t_i}-B_{t_{i-1}}=\Sigma_{i=1}^k\sqrt{t_i-t_{i-1}}Z_{t_i}$
#
# Suppose we have another standard normal random variable $Z_{t_2} \sim N(0,1)$ we know $B_{t_2}-B_{t_1} \sim N(0,t_2-t_1)$
#
# If we scale $Z_{t_2}$ by $\sqrt{t_2-t_1}$ we will find $\sqrt{t_2-t_1}Z_{t_2}=B_{t_2}-B_{t_1}$ in the sense of their distribution functions.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
# Simulation parameters
T = 10000  # Number of steps
time_step = 1   # Time step size
n_particles = 100  # Number of particles (for averaging)

# Generate random displacements
displacements = np.random.normal(0, np.sqrt(time_step), (n_particles, T))

# Cumulative sum to simulate position over time (x(t))
positions = np.cumsum(displacements, axis=1)

# Time array
time = np.arange(T) * time_step

# Calculate squared displacement and mean squared displacement (MSD)
squared_displacement = positions**2
msd = np.mean(squared_displacement, axis=0)

# %%
# Plot the Brownian motion for one particle
plt.figure(figsize=(10, 5))
plt.plot(time, positions[0], label='Particle trajectory')
plt.xlabel('Time')
plt.ylabel('Position')
plt.title('1D Brownian Motion of a Single Particle')
plt.grid()
plt.legend()
plt.show()

# %%
# Define the MSD fitting function (MSD = 2*D*t)
def msd_function(t, D):
    return 2 * D * t

# Fit the MSD to find the diffusion coefficient
params, covariance = curve_fit(msd_function, time, msd)
D = params[0]

# %%
# Plot the MSD and the fitted curve
plt.figure(figsize=(10, 5))
plt.plot(time, msd, label='MSD (simulated)', marker='o')
plt.plot(time, msd_function(time, D), label=f'Fitted MSD (2Dt), D={D:.4f}', color='red')
plt.xlabel('Time')
plt.ylabel('Mean Square Displacement')
plt.title('Mean Square Displacement of 1D Brownian Motion')
plt.legend()
plt.grid()
plt.show()

# %%
print(f"Fitted Diffusion Coefficient: D = {D:.4f}")
# Out:
# Fitted Diffusion Coefficient: D = 0.5525

# %% [markdown]
# # In 2D
#
# https://dec41.user.srcf.net/canvas/brownian

# %%
displacements_x = np.random.normal(0, np.sqrt(time_step), (n_particles, T))
displacements_y = np.random.normal(0, np.sqrt(time_step), (n_particles, T))

positions_x = np.cumsum(displacements_x, axis=1)
positions_y = np.cumsum(displacements_y, axis=1)

squared_displacement_2D = positions_x**2 + positions_y**2
msd_2D = np.mean(squared_displacement_2D, axis=0)

plt.figure(figsize=(7, 7))
plt.plot(positions_x[0], positions_y[0], label='Particle trajectory')
plt.xlabel('X Position')
plt.ylabel('Y Position')
plt.title('2D Brownian Motion of a Single Particle')
plt.grid()
plt.legend()
plt.axis('equal')
plt.show()
